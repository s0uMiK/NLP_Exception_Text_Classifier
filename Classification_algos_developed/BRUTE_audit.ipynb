# %%
import pandas as pd

# %%
import nltk 
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv('Training Data -Table 1.csv')
df.drop(['Queue', 'Process','Unnamed: 4'],axis=1,inplace=True)

# %%
stop_words = stopwords.words('english')
stemmer = SnowballStemmer('english')

text_cleaning_re = "@\S+|https?:\S+|http?:\S|[^A-Za-z0-9]+"

# %%
def preprocess(text, stem=False):
  text = re.sub(text_cleaning_re, ' ', str(text).lower()).strip()
  tokens = []
  for token in text.split():
    if token not in stop_words:
      if stem:
        tokens.append(stemmer.stem(token))
      else:
        tokens.append(token)
  return " ".join(tokens)

# %%
 import re

# %%
for i in range(len(df.ExceptionMessage)):
  df.ExceptionMessage[i] = df.ExceptionMessage[i].split()

# %%
df.head(5)
# Out:
#                                     ExceptionMessage       ExceptionType
# 0       [Invite, not, found, in, both, CBS, mailbox]  Business Exception
# 1  [Interviewer, xxxx, mail, ID, not, found, in, ...  Business Exception
# 2  [Invite, not, found, in, both, TAX, and, PAS, ...  Business Exception
# 3  [InternalFailed, to, evaluate, expression, 'Re...    System Exception
# 4  [Could, not, execute, code, stage, because, ex...    System Exception

# %%
df1 = pd.read_csv('Keywords for tagging-Table 1.csv')

# %%
for j in range(len(df1.SystemException)):
  df1.SystemException[j] = preprocess(df1.SystemException[j])
  df1.SystemException[j] = df1.SystemException[j].split()

# %%
key_sys=[]
for key in df1.SystemException:
  for key1 in key:
    key_sys.append(key1)
key_sys = list(set(key_sys))

# %%
key_sys

# %%
for j in range(len(df1.BusinessException)):
  df1.BusinessException[j] = preprocess(df1.BusinessException[j])
  df1.BusinessException[j] = df1.BusinessException[j].split()

# %%
key_bus=[]
for key in df1.BusinessException:
  for key1 in key:
    key_bus.append(key1)
key_bus = list(set(key_bus))

# %%
key_bus.remove('nan')

# %%
key_bus

# %%
Bis_check =  any(item in key_bus for item in df.ExceptionMessage[0])

# %%
if Bis_check == True:
  print("Business Exception")
else :
  print("not")
# Out:
# Business Exception

# %%
Sys_check =  any(item in key_sys for item in df.ExceptionMessage[1])

# %%
if Sys_check == True:
  print("System Exception")
else :
  print("not")
# Out:
# not

# %%
# key_bus = ['contain','error','fields','mandatory','missing','found','template','file','field', 'input','processed','mail','invite','manually','id']
# key_sys = ['internal','exception','memory','expression','code','stage','site','perform','evaluate','cleanup','time','hresult','failed','operation','unable','issue','data','fetch','unexpected','automatically','set','launch']
# op1 = 0 
def brute_force_audit(txt):
  Bis_check =  any(item in key_bus for item in txt)
  Sys_check =  any(item in key_sys for item in txt)
  if Bis_check == True :
    op=['1']
    for j in txt:
      op.append(j)
  elif Sys_check == True :
    op=['2']
    for j in txt:
      op.append(j)
  return op

# %%
s=" "
s = s.join(op1)
df.ExceptionMessage[0] = s

# %%
df.ExceptionMessage[0]
# Out:
# '1 Interviewer xxxx mail ID not found in invite.'

# %%
from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer

# %%
words =['contain', 'contains']
porter = PorterStemmer()
for i in range(len(words)):
  words[i] = porter.stem(words[i])

# %%
words
# Out:
# ['contain', 'contain']

# %%
bds = words
bds
# Out:
# ['contain', 'contain']
